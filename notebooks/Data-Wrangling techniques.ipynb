# %%
import numpy as np
import pandas as pd

# %%
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  origin   mpg
# 0            8         307.0       130.0  3504.0          12.0          70       1  18.0
# 1            8         350.0       165.0  3693.0          11.5          70       1  15.0
# 2            8         318.0       150.0  3436.0          11.0          70       1  18.0
# 3            8         304.0       150.0  3433.0          12.0          70       1  16.0
# 4            8         302.0       140.0  3449.0          10.5          70       1  17.0
# 5            8         429.0       198.0  4341.0          10.0          70       1  15.0
# 6            8         454.0       220.0  4354.0           9.0          70       1  14.0
# 7            8         440.0       215.0  4312.0           8.5          70       1  14.0
# 8            8         455.0       225.0  4425.0          10.0          70       1  14.0
# ...

# %%
arr1=np.array([[1,2,3],[4,5,6],['?','?','?']])
print(pd.DataFrame(arr1))
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  ?  ?  ?

# %%
headers=['sample1','sample2','sample3']
df1=pd.DataFrame(arr1)
df1.columns=headers
print(df1)
# Out:
#   sample1 sample2 sample3
# 0       1       2       3
# 1       4       5       6
# 2       ?       ?       ?

# %%
#Filling null values
#df1.replace('?',np.nan,inplace=True)
df1.fillna(value=3)
#print(df1)
# Out:
#   sample1 sample2 sample3
# 0       1       2       3
# 1       4       5       6
# 2       3       3       3

# %%
#Removing null values
df2=df1.dropna()
print(df2)
# Out:
#   sample1 sample2 sample3
# 0       1       2       3
# 1       4       5       6

# %%
#loc and iloc functions
x=df2.iloc[0]
print(x)
y=df2.loc[0,'sample1']
print(y)
# Out:
# sample1    1
# sample2    2
# sample3    3
# Name: 0, dtype: object
# 1

# %%
avg_sample1=df1['sample1'].astype('float').mean(axis=0)

print(avg_sample1)
# Out:
# 2.5

# %%
df1['sample1'].value_counts()
# Out:
# 1    1
# 4    1
# Name: sample1, dtype: int64

# %%
df1['sample1'].value_counts().idxmax()
# Out:
# '1'

# %%
#Reading data from csv files
filename="Auto.csv"
df=pd.read_csv(filename)
print(df.to_string())
print(type(df))
arr1=df.to_numpy()
print(arr1)
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  origin   mpg
# 0            8         307.0       130.0  3504.0          12.0          70       1  18.0
# 1            8         350.0       165.0  3693.0          11.5          70       1  15.0
# 2            8         318.0       150.0  3436.0          11.0          70       1  18.0
# 3            8         304.0       150.0  3433.0          12.0          70       1  16.0
# 4            8         302.0       140.0  3449.0          10.5          70       1  17.0
# 5            8         429.0       198.0  4341.0          10.0          70       1  15.0
# 6            8         454.0       220.0  4354.0           9.0          70       1  14.0
# 7            8         440.0       215.0  4312.0           8.5          70       1  14.0
# 8            8         455.0       225.0  4425.0          10.0          70       1  14.0
# ...

# %%
#Printing first 5 the columns
df.head(5)
# Out:
#    cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0          8         307.0       130.0  3504.0          12.0          70
# 1          8         350.0       165.0  3693.0          11.5          70
# 2          8         318.0       150.0  3436.0          11.0          70
# 3          8         304.0       150.0  3433.0          12.0          70
# 4          8         302.0       140.0  3449.0          10.5          70
#
#    origin   mpg
# 0       1  18.0
# 1       1  15.0
# 2       1  18.0
# 3       1  16.0
# 4       1  17.0

# %%
df.mean()
# Out:
# cylinders          5.471939
# displacement     194.411990
# horsepower       104.469388
# weight          2977.584184
# acceleration      15.541327
# model_year        75.979592
# origin             1.576531
# mpg               23.445918
# dtype: float64

# %%
df.describe()
# Out:
#         cylinders  displacement  horsepower       weight  acceleration  \
# count  392.000000    392.000000  392.000000   392.000000    392.000000
# mean     5.471939    194.411990  104.469388  2977.584184     15.541327
# std      1.705783    104.644004   38.491160   849.402560      2.758864
# min      3.000000     68.000000   46.000000  1613.000000      8.000000
# 25%      4.000000    105.000000   75.000000  2225.250000     13.775000
# 50%      4.000000    151.000000   93.500000  2803.500000     15.500000
# 75%      8.000000    275.750000  126.000000  3614.750000     17.025000
# max      8.000000    455.000000  230.000000  5140.000000     24.800000
#
#        model_year      origin         mpg
# count  392.000000  392.000000  392.000000
# mean    75.979592    1.576531   23.445918
# std      3.683737    0.805518    7.805007
# min     70.000000    1.000000    9.000000
# 25%     73.000000    1.000000   17.000000
# 50%     76.000000    1.000000   22.750000
# ...

# %%
print(df.groupby('model_year').weight.agg(['count','min','max']))
# Out:
#             count     min     max
# model_year
# 70             29  1835.0  4732.0
# 71             27  1613.0  5140.0
# 72             28  2100.0  4633.0
# 73             40  1867.0  4997.0
# 74             26  1649.0  4699.0
# 75             30  1795.0  4668.0
# 76             34  1795.0  4380.0
# 77             28  1825.0  4335.0
# 78             36  1800.0  4080.0
# 79             29  1915.0  4360.0
# 80             27  1845.0  3381.0
# 81             28  1755.0  3725.0
# 82             30  1965.0  3015.0

# %%
print(df.groupby('cylinders').weight.mean())
# Out:
# cylinders
# 3    2398.500000
# 4    2305.110553
# 5    3103.333333
# 6    3202.120482
# 8    4114.718447
# Name: weight, dtype: float64

# %%
print(df.duplicated().sum())
# Out:
# 0
