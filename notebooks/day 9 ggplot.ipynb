# %%
import pandas as pd
from plotnine import ggplot
df=pd.read_csv("Iris.csv")
ggplot(df)
# Out:
# <ggplot: (144357350857)>

# %%
import pandas as pd
from plotnine import ggplot,aes,geom_bar
df=pd.read_csv("Iris.csv")
ggplot(df) + aes(x="Species",y="SepalLengthCm")+geom_bar()
# Out:
# ---------------------------------------------------------------------------
# PlotnineError                             Traceback (most recent call last)
# File C:\Program Files\Python310\lib\site-packages\IPython\core\formatters.py:707, in PlainTextFormatter.__call__(self, obj)
#     700 stream = StringIO()
#     701 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     702     self.max_width, self.newline,
#     703     max_seq_length=self.max_seq_length,
#     704     singleton_pprinters=self.singleton_printers,
#     705     type_pprinters=self.type_printers,
#     706     deferred_pprinters=self.deferred_printers)
# --> 707 printer.pretty(obj)
#     708 printer.flush()
#     709 return stream.getvalue()
#
# File C:\Program Files\Python310\lib\site-packages\IPython\lib\pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
#     409                         and callable(cls.__dict__.get('__repr__')):
# --> 410                     return _repr_pprint(obj, self, cycle)
#     412     return _default_pprint(obj, self, cycle)
#     413 finally:
#
# File C:\Program Files\Python310\lib\site-packages\IPython\lib\pretty.py:778, in _repr_pprint(obj, p, cycle)
#     776 """A pprint that just redirects to the normal repr function."""
#     777 # Find newlines and replace them with p.break_()
# --> 778 output = repr(obj)
#     779 lines = output.splitlines()
#     780 with p.group():
#
# File C:\Program Files\Python310\lib\site-packages\plotnine\ggplot.py:95, in ggplot.__repr__(self)
#      91 def __repr__(self):
#      92     """
#      93     Print/show the plot
#      94     """
# ---> 95     self.__str__()
#      96     return '<ggplot: (%d)>' % self.__hash__()
#
# File C:\Program Files\Python310\lib\site-packages\plotnine\ggplot.py:86, in ggplot.__str__(self)
#      82 def __str__(self):
#      83     """
#      84     Print/show the plot
#      85     """
# ---> 86     self.draw(show=True)
#      88     # Return and empty string so that print(p) is "pretty"
#      89     return ''
#
# File C:\Program Files\Python310\lib\site-packages\plotnine\ggplot.py:203, in ggplot.draw(self, return_ggplot, show)
#     201 self = deepcopy(self)
#     202 with plot_context(self, show=show):
# --> 203     self._build()
#     205     # setup
#     206     figure, axs = self._create_figure()
#
# File C:\Program Files\Python310\lib\site-packages\plotnine\ggplot.py:303, in ggplot._build(self)
#     300 layout.map_position(layers)
#     302 # Apply and map statistics
# --> 303 layers.compute_statistic(layout)
#     304 layers.map_statistic(self)
#     306 # Prepare data in geoms
#     307 # e.g. from y and width to ymin and ymax
#
# File C:\Program Files\Python310\lib\site-packages\plotnine\layer.py:71, in Layers.compute_statistic(self, layout)
#      69 def compute_statistic(self, layout):
#      70     for l in self:
# ---> 71         l.compute_statistic(layout)
#
# File C:\Program Files\Python310\lib\site-packages\plotnine\layer.py:333, in layer.compute_statistic(self, layout)
#     331 data = self.stat.use_defaults(data)
#     332 data = self.stat.setup_data(data)
# --> 333 data = self.stat.compute_layer(data, params, layout)
#     334 self.data = data
#
# File C:\Program Files\Python310\lib\site-packages\plotnine\stats\stat.py:276, in stat.compute_layer(cls, data, params, layout)
#     273     pscales = layout.get_scales(pdata['PANEL'].iat[0])
#     274     return cls.compute_panel(pdata, pscales, **params)
# --> 276 return groupby_apply(data, 'PANEL', fn)
#
# File C:\Program Files\Python310\lib\site-packages\plotnine\utils.py:638, in groupby_apply(df, cols, func, *args, **kwargs)
#     634 lst = []
#     635 for _, d in df.groupby(cols):
#     636     # function fn should be free to modify dataframe d, therefore
#     637     # do not mark d as a slice of df i.e no SettingWithCopyWarning
# --> 638     lst.append(func(d, *args, **kwargs))
#     639 return pd.concat(lst, axis=axis, ignore_index=True)
#
# File C:\Program Files\Python310\lib\site-packages\plotnine\stats\stat.py:274, in stat.compute_layer.<locals>.fn(pdata)
#     272     return pdata
#     273 pscales = layout.get_scales(pdata['PANEL'].iat[0])
# --> 274 return cls.compute_panel(pdata, pscales, **params)
#
# File C:\Program Files\Python310\lib\site-packages\plotnine\stats\stat.py:308, in stat.compute_panel(cls, data, scales, **params)
#     306 stats = []
#     307 for _, old in data.groupby('group'):
# --> 308     new = cls.compute_group(old, scales, **params)
#     309     unique = uniquecols(old)
#     310     missing = unique.columns.difference(new.columns)
#
# File C:\Program Files\Python310\lib\site-packages\plotnine\stats\stat_count.py:60, in stat_count.compute_group(cls, data, scales, **params)
#      58 if ('y' in data) or ('y' in params):
#      59     msg = 'stat_count() must not be used with a y aesthetic'
# ---> 60     raise PlotnineError(msg)
#      62 weight = data.get('weight', np.ones(len(x), dtype=int))
#      63 width = params['width']
#
# PlotnineError: 'stat_count() must not be used with a y aesthetic'

# %%
from plotnine import ggplot, aes,geom_point
ggplot(df) + aes(x="Species",y="SepalLengthCm")+geom_point()
# Out:
# <ggplot: (144384708987)>

# %%
from plotnine import ggplot,aes,geom_boxplot
df=pd.read_csv("Iris.csv")
print(df)
ggplot(df)+aes(x="Species",y="SepalLengthCm")+geom_boxplot()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]
# <ggplot: (144387954896)>

# %%
from plotnine import ggplot,aes,geom_line
df=pd.read_csv("Iris.csv")
print(df)
ggplot(df)+aes(x="Species",y="SepalLengthCm")+geom_line()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]
# <ggplot: (144390052756)>
