# %%
import matplotlib.pyplot as plt
import numpy as np

#xpoints = np.array([0, 6])
#ypoints = np.array([0, 6])
x=[11,15,9,14,15]
y=[1,2,3,4,5]
plt.plot(x,y,marker='o',ls='dotted',lw=5)
plt.show()

# %%
#Plotting Without Line
#xpoints = np.array([0,3, 6])
#ypoints = np.array([0,3, 6])

plt.plot(xpoints, ypoints,'o')
plt.show()

# %%
#Default X-Points
#ypoints = np.array([3, 8, 1, 10, 5, 7])
x=[1,2,3,4,5]
y=[1,2,3,4,5]
#plt.plot(ypoints)
#Marker in matplotlib
plt.plot(x,y,marker='<')
plt.show()

# %%
#Format strings
ypoints = np.array([3, 8, 1, 10])

#plt.plot(ypoints, 'o:r')

plt.plot(ypoints, marker = '>', ms = 50, mec = 'g', mfc = '#FFFFFF',ls='dashed',c='k')

plt.show()
#(0,0,0)(255,255,255)

# %%
#Line arguments
ypoints = np.array([3, 8, 1, 10])

#plt.plot(ypoints, linestyle = 'dotted')
#plt.plot(ypoints, linestyle = 'dashed')
#plt.plot(ypoints, c = 'r')
plt.plot(ypoints,ls='dotted', c = 'r',lw='20')
plt.show()

# %%
#Multiple lines
x1=[1,2,3,4]
y1=[15,11,9,20]
#y1 = np.array([3, 8, 1, 10])
x2=[1,2,3,4]
y2=[3,8,1,7]
#y2 = np.array([6, 2, 7, 11])

plt.plot(x1,y1,c='r')
plt.plot(x2,y2,c='b')
plt.title("PGDBDA class",loc="right")
plt.show()

# %%
#Labels
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, c = 'r',lw='20')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
#plt.title("PGDBDA class")
plt.title("PGDBDA class",loc='left')
plt.show()

# %%
#Grid lines
#xpoints = np.array([0, 6])
#ypoints = np.array([0, 6])
x=[2001,2002,2005,2007,2022]
y=[70,80,89,90,100]
#plt.plot(xpoints, ypoints)
plt.xlabel("Year of Production")
plt.ylabel("Price")
plt.title("Petrol price")
plt.plot(x,y)
plt.grid(axis='y',color='green',ls='--',lw=0.5)
#plt.grid(axis='x')
#plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.show()

# %%
#Subplot
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.title("SALES")
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.title("INCOME")
plt.plot(x,y)

plt.suptitle("SHOP")

plt.show()

# %%
#Scatter plots
#x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
#y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
x=[1,2,3,4,5]
y=[1,2,3,4,5]
plt.scatter(x, y)

plt.show()

# %%
#scatter plots
x1 = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y1 = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
x2 = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y2 = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x1,y1)
plt.scatter(x2,y2)
plt.show()

# %%
#scatter plot with different colors
#x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
#y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
#colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])
#colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])
#plt.scatter(x, y, c=colors)
#Color map
x=[5,3,2,11,15,16]
y=[8,2,6,9,12,13]
#mycolors=np.array(["purple","green","blue","pink","orange","cyan"])
sizes=np.array([100,20,300,30,400,40])
#plt.scatter(x,y,c=mycolors)
colors=np.array([0,10,20,30,40,50])
plt.scatter(x, y, c=colors,cmap='viridis',s=sizes)
plt.colorbar()

plt.show()

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes,alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %%
#Bar charts
#x = np.array(["A", "B", "C", "D"])
#y = np.array([3, 8, 1, 10])
x=[2010,2012,2016,2018]
y=[40,40,45,60]
plt.xlabel("Year")
plt.ylabel("Weight")
plt.barh(x,y,color='r',height=2)
#plt.bar(x,y,color='g',width=0.1)
#plt.barh(x,y,color='g',height=0.1)
plt.show()

# %%
#Histogram
'''x = np.array([1,2,11,12,     21,22,
     31,32,33,34,35,
     41,42,43,44,45,46,47,48,
     51,52,53,54,55,56,57,58,59,
     61,62,63,64,65,66,
     71,72,73,74,75,67,
     81,82,83,
     91,92,
     101])
 '''
#x=np.random.randint(20,size=(20))
x=[0,5,10,15,20,25,35,40,45,50]
marks = np.array([98, 89, 45, 56, 78, 25, 43, 33, 54, 100])
#fig, axis = plt.subplots(figsize =(10, 5))
#plt.hist(marks)
plt.hist(marks,bins=[0,20,40,60,80,100])
#plt.hist(x)
plt.show()

# %%
#Pie charts
y = np.array([35, 25, 25, 15])

#plt.pie(y)
#mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

#plt.pie(y, labels = mylabels, startangle = 90)

#myexplode = [0.2, 0, 0, 0]
#myexplode = [0, 0.2, 0, 0]
#plt.pie(y, labels = mylabels, explode = myexplode)
#plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
#plt.show() 
myexp=[0,0,0.5,0]
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels,startangle=90,explode=myexp,shadow=True)
plt.legend()
plt.show()

# %%
#Seaborn
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot([0, 1, 2, 3, 4, 5])

plt.show()
# Out:
# C:\Users\jobsf\AppData\Local\Temp\ipykernel_16096\1115224445.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0, 1, 2, 3, 4, 5])

# %%
#Heatmap seaborn
# importing the modules
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
  
# generating 2-D 10x10 matrix of random numbers
# from 1 to 100
#data = np.random.randint(low = 1,high = 100,size = (10, 10))
data=np.array([[1,2,3,4],[11,12,13,14],[5,6,7,8],[1,16,17,18]])
print("The data to be plotted:\n")
print(data)
  
# plotting the heatmap
hm = sn.heatmap(data = data)
  
# displaying the plotted heatmap
plt.show()
# Out:
# The data to be plotted:
#
# [[ 1  2  3  4]
#  [11 12 13 14]
#  [ 5  6  7  8]
#  [ 1 16 17 18]]

# %%
import seaborn as sn
import matplotlib.pyplot as plt
import pandas as pd
data=pd.read_csv("bestsellers.csv")
c1=pd.DataFrame(data)
print(c1.head())
print(c1.corr())
#print(max(c1.corr()))
dataplot=sn.heatmap(c1.corr(),cmap="YlGnBu",annot=True)
#plt.scatter(c1['Year'],c1['Reviews'])
#plt.show()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction
#              User Rating   Reviews     Price      Year
# User Rating     1.000000 -0.001729 -0.133086  0.242383
# Reviews        -0.001729  1.000000 -0.109182  0.263560
# ...
